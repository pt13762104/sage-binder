# %%
implicit_multiplication(True)
abs(x)=sqrt(x^2)
f1 = 1
plot(f1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=expand((5+x^9)^9)

# %%
plot(f(x))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(integrate(x^(1/2),x))
# Out:
# 2/3*x^(3/2)

# %%
x,y=var('x y')
solve([2*x+3-abs(x-7)],[x],algorithm='sympy')
# Out:
# [x == (4/3)]

# %%
show(solve(x^9==1,x))
# Out:
# [x == e^(2/9*I*pi), x == e^(4/9*I*pi), x == 1/2*I*sqrt(3) - 1/2, x == e^(8/9*I*pi), x == e^(-8/9*I*pi), x == -1/2*I*sqrt(3) - 1/2, x == e^(-4/9*I*pi), x == e^(-2/9*I*pi), x == 1]

# %%
solve([4*1+5*x+7*2+8*3+9*y-66/10*(1+x+2+3+y),1+x+2+3+y-10],[x,y])
# Out:
# [[x == 3, y == 1]]

# %%
f
# Out:
# x |--> x^81 + 45*x^72 + 900*x^63 + 10500*x^54 + 78750*x^45 + 393750*x^36 + 1312500*x^27 + 2812500*x^18 + 3515625*x^9 + 1953125

# %%
solve([1*0+2*0+3*2+4*x+5*10+6*12+7*7+8*6+9*4+10*1==606/100*y,y==0+0+2+x+10+12+7+6+4+1],[x,y])
# Out:
# [[x == 8, y == 50]]

# %%
solve([2/x==y/3,2*y==(1/4)*(3*x)],[x,y])
# Out:
# [[x == -4, y == (-3/2)], [x == 4, y == (3/2)]]

# %%
a=var('a')
g(x,a)=(a/100)*x
h(x,a)=x+g(x)
s(x,a)=(1+a/100)^2*x-x
solve(s(x,12/10)==48288,x)
# Out:
# [x == 2000000]

# %%
solve([11/10*x+108/100*y==120,1/10*x+8/100*y==10],[x,y])
# Out:
# [[x == 60, y == 50]]

# %%
show(solve([abs(x-y)==4,5*x==10*y+x],x,y))
# Out:
# [[x == (-20/3), y == (-8/3)], [x == (20/3), y == (8/3)]]

# %%
show(solve(f(x),x))
# Out:
# [x == 5^(1/9)*(-1)^(1/9)*e^(2/9*I*pi), x == 5^(1/9)*(-1)^(1/9)*e^(4/9*I*pi), x == 1/2*I*5^(1/9)*sqrt(3)*(-1)^(1/9) - 1/2*5^(1/9)*(-1)^(1/9), x == 5^(1/9)*(-1)^(1/9)*e^(8/9*I*pi), x == 5^(1/9)*(-1)^(1/9)*e^(-8/9*I*pi), x == -1/2*I*5^(1/9)*sqrt(3)*(-1)^(1/9) - 1/2*5^(1/9)*(-1)^(1/9), x == 5^(1/9)*(-1)^(1/9)*e^(-4/9*I*pi), x == 5^(1/9)*(-1)^(1/9)*e^(-2/9*I*pi), x == 5^(1/9)*(-1)^(1/9)]

# %%
show(solve([x+y==4*10^6,1011/1000*x-1012/1000*y==807200],[x,y]))
# Out:
# [[x == 2400000, y == 1600000]]

# %%
t=var('t')
s=var('s')
parametric_plot3d([(5*cos(t)*sin(s)),(5*sin(t)*sin(s)),(5*cos(s))],(t,0,2*pi),(s,0,pi))
# Out:
# Graphics3d Object

# %%
parametric_plot((sin(t),cos(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
implicit_plot(x^2+y^2-25,(x,-6,6),(y,-6,6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(x^2 + y^2, (x,-2,2), (y,-2,2))
# Out:
# Graphics3d Object

# %%
parametric_plot3d((t,s,s),(t,-5,5),(s,-5,5))
# Out:
# Graphics3d Object

# %%
solve([sin(x)-cos(x)],[x],algorithm='sympy')
# Out:
# [ImageSet(Lambda(_n, 2*_n*pi + 5*pi/4), Integers),
#  ImageSet(Lambda(_n, 2*_n*pi + pi/4), Integers)]

# %%
f
# Out:
# x |--> x^81 + 45*x^72 + 900*x^63 + 10500*x^54 + 78750*x^45 + 393750*x^36 + 1312500*x^27 + 2812500*x^18 + 3515625*x^9 + 1953125

# %%
factor(f1)
# Out:
# 1

# %%
z=var('z')

# %%
factor(z^2+1)
# Out:
# z^2 + 1

# %%
show(f)
# Out:
# x |--> x^81 + 45*x^72 + 900*x^63 + 10500*x^54 + 78750*x^45 + 393750*x^36 + 1312500*x^27 + 2812500*x^18 + 3515625*x^9 + 1953125

# %%
f.parent()
# Out:
# Callable function ring with argument x

# %%
CC.category()
# Out:
# Join of Category of fields and Category of infinite sets and Category of complete metric spaces

# %%
M(x)=x^5+-5*x^2+7*x+1
j=(solve(diff(M,x),x,solution_dict=True)[2][x])
show(M(j))
# Out:
# 1/32*(sqrt(1/15)*sqrt((15*(2/225*I*sqrt(2113)*sqrt(15) + 2)^(2/3) + 28)/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)) - sqrt(-(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3) + 60*sqrt(1/15)/sqrt((15*(2/225*I*sqrt(2113)*sqrt(15) + 2)^(2/3) + 28)/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)) - 28/15/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)))^5 - 5/4*(sqrt(1/15)*sqrt((15*(2/225*I*sqrt(2113)*sqrt(15) + 2)^(2/3) + 28)/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)) - sqrt(-(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3) + 60*sqrt(1/15)/sqrt((15*(2/225*I*sqrt(2113)*sqrt(15) + 2)^(2/3) + 28)/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)) - 28/15/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)))^2 + 7/2*sqrt(1/15)*sqrt((15*(2/225*I*sqrt(2113)*sqrt(15) + 2)^(2/3) + 28)/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)) - 7/2*sqrt(-(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3) + 60*sqrt(1/15)/sqrt((15*(2/225*I*sqrt(2113)*sqrt(15) + 2)^(2/3) + 28)/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)) - 28/15/(2/225*I*sqrt(2113)*sqrt(15) + 2)^(1/3)) + 1

# %%
minimize_constrained(1/(16*x)+1/(4*y)+1/(1-x-y),[(0,1),(0,1)],[.1,.1])
# Out:
# (0.14285711009321744, 0.2857143750492189)

# %%
p(x)=sqrt(sqrt((2/pi)^(1-cos(x*pi)))*2^x)*gamma(x/2+1)

# %%
plot(p(x),xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
R.<x,y> = PolynomialRing(QQ)

# %%
f1=(3x^2y+5x*y-2)*(4x+3y)
f2=6x^2*(2x*y+3/2*y^2+10/3*y)

# %%
expand(f1-f2)
# Out:
# 15*x*y^2 - 8*x - 6*y

# %%
expand((5x-y)^2)
# Out:
# 25*x^2 - 10*x*y + y^2

# %%
expand((1/3*x+2y)^3)
# Out:
# 1/27*x^3 + 2/3*x^2*y + 4*x*y^2 + 8*y^3

# %%
factor(x^4-4x^3-7x^2+8x+10)
# Out:
# (x - 5) * (x + 1) * (x^2 - 2)

# %%
factor((x+y+z)^3-x^3-y^3-z^3)
# Out:
# 3*(x + y)*(x + z)*(y + z)

# %%
f3=(3*x^4*y-9*x^3*y^2-21*x^2*y^2)

# %%
show(f3.quo_rem(3*x^2*y-2*y+2x))
# Out:
# (x^2 - 3*x*y - 7*y + 8/3, -2*x^3 - 6*x*y^2 + 14*x*y - 14*y^2 - 16/3*x + 16/3*y)

# %%
show(integrate(e^(x+6)*x^6*((x+1)^6),x))
# Out:
# (x^12*e^6 - 12*x^11*e^6 + 132*x^10*e^6 - 1320*x^9*e^6 + 11880*x^8*e^6 - 95040*x^7*e^6 + 665280*x^6*e^6 - 3991680*x^5*e^6 + 19958400*x^4*e^6 - 79833600*x^3*e^6 + 239500800*x^2*e^6 - 479001600*x*e^6 + 479001600*e^6)*e^x + 6*(x^11*e^6 - 11*x^10*e^6 + 110*x^9*e^6 - 990*x^8*e^6 + 7920*x^7*e^6 - 55440*x^6*e^6 + 332640*x^5*e^6 - 1663200*x^4*e^6 + 6652800*x^3*e^6 - 19958400*x^2*e^6 + 39916800*x*e^6 - 39916800*e^6)*e^x + 15*(x^10*e^6 - 10*x^9*e^6 + 90*x^8*e^6 - 720*x^7*e^6 + 5040*x^6*e^6 - 30240*x^5*e^6 + 151200*x^4*e^6 - 604800*x^3*e^6 + 1814400*x^2*e^6 - 3628800*x*e^6 + 3628800*e^6)*e^x + 20*(x^9*e^6 - 9*x^8*e^6 + 72*x^7*e^6 - 504*x^6*e^6 + 3024*x^5*e^6 - 15120*x^4*e^6 + 60480*x^3*e^6 - 181440*x^2*e^6 + 362880*x*e^6 - 362880*e^6)*e^x + 15*(x^8*e^6 - 8*x^7*e^6 + 56*x^6*e^6 - 336*x^5*e^6 + 1680*x^4*e^6 - 6720*x^3*e^6 + 20160*x^2*e^6 - 40320*x*e^6 + 40320*e^6)*e^x + 6*(x^7*e^6 - 7*x^6*e^6 + 42*x^5*e^6 - 210*x^4*e^6 + 840*x^3*e^6 - 2520*x^2*e^6 + 5040*x*e^6 - 5040*e^6)*e^x + (x^6*e^6 - 6*x^5*e^
# ...

# %%
x,y=var('x y')

# %%
solve(10^x-2399*floor((10^x)/2399)-1,x,algorithm="giac")
# Out:
# // Giac share root-directory:/home/a/mambaforge/envs/sage/lib/python3.10/site-packages/sage/libs/giac/../../../../../../share/giac/
# // Giac share root-directory:/home/a/mambaforge/envs/sage/lib/python3.10/site-packages/sage/libs/giac/../../../../../../share/giac/
# Added 0 synonyms
# Warning, argument is not an equation, solving 10^sageVARx-2399*floor(10^sageVARx/2399)-1=0
# Unable to isolate sageVARx in exp(sageVARx*ln(10))-2399*floor(exp(sageVARx*ln(10))/2399)-1, switching to approx. solutions
# Solving by bisection with change of variable x=tan(t) and t=-1.57..1.57. Try fsolve(equation,x=guess) for iterative solver or fsolve(equation,x=xmin..xmax) for bisection.
# Equation: exp(sageVARx*ln(10))-2399*floor(exp(sageVARx*ln(10))/2399)-1
# [1.00213650836000e-15]

# %%
show(diff(tan(x),x))
# Out:
# tan(x)^2 + 1

# %%
def sgn(x):
    if x!=0:
        return abs(x)/x
    else:
        return 0
implicit_plot(abs(x)+abs(y)+abs(x)*sgn(abs(x)-abs(y))+abs(y)*sgn(abs(y)-abs(x))-5,(x,-10,10),(y,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive
